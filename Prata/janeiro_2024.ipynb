# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib as mtlb

# %%
df_janeiro = pd.ExcelFile(r'C:\Users\JOSEP\Documents\Projeto--An-lise-da-Desigualdade-de-Renda-e-Emprego-no-Brasil\Bronze\1-tabelas_janeiro_de_2024.xlsx')
print(df_janeiro.sheet_names)
# Out:
# ['CAGED', 'Sumário', 'Tabela 1', 'Tabela 2', 'Tabela 3', 'Tabela 4', 'Tabela 5', 'Tabela 5.1', 'Tabela 6', 'Tabela 6.1', 'Tabela 7', 'Tabela 7.1', 'Tabela 8', 'Tabela 8.1', 'Tabela 9']

# %%
df_janeiro = pd.read_excel(r'C:\Users\JOSEP\Documents\Projeto--An-lise-da-Desigualdade-de-Renda-e-Emprego-no-Brasil\Bronze\1-tabelas_janeiro_de_2024.xlsx',sheet_name=7)
df_janeiro
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0          NaN  TABELA 5.1 - EVOLUÇÃO DE ESTOQUE, ADMISSÕES, D...        NaN
# 1          NaN                                                NaN        NaN
# 2          NaN                                                NaN        NaN
# 3          NaN                                                Mês    Estoque
# 4          NaN                                       Janeiro/2020   39553644
# 5          NaN                                     Fevereiro/2020   39770913
# 6          NaN                                         Março/2020   39475853
# 7          NaN                                         Abril/2020   38494275
# 8          NaN                                          Maio/2020   38095906
# 9          NaN                                         Junho/2020   38042432
# 10         NaN                                         Julho/2020   38150815
# ...
